# %%
# Upset Constraints

from re import T
import pandas as pd
import requests
import io
from math import *
from gurobipy import *
import matplotlib.pyplot as plt

# Pull in initial CSV file from Github and transform it into a Dataframe

url = "https://raw.githubusercontent.com/camjm21/4133project/main/March%20Madness.csv"
download = requests.get(url).content
df = pd.read_csv(io.StringIO(download.decode('utf-8')))
df.set_index('TEAM', inplace=True)

#Pull in actual 2019 bracket results
url2 = "https://raw.githubusercontent.com/camjm21/4133project/main/2019ActualBracket.csv"
download2 = requests.get(url2).content
origninalBracket = pd.read_csv(io.StringIO(download2.decode('utf-8')))
origninalBracket.rename(columns = {"Unnamed: 0": "TEAM"}, inplace = True)
origninalBracket.set_index('TEAM', inplace = True)


# Create dictionary for round one matchups, every team will be a key, with their opponent being the value
teams = list(df.index)
values = [0] * len(teams)
for i in range(len(teams)):
    if i % 2 == 0:
        values[i+1] = teams[i]
    else:
        values[i-1] = teams[i]

firstround = dict(zip(teams, values))

# Create dataframe to put results in
results = pd.DataFrame(index=teams,columns=['First Round','Second Round', 'Third Round', 'Fourth Round', 'Fifth Round', 'Sixth Round'])

# Put first round probabilities in
results['First Round'] = [df.loc[i, firstround[i]] for i in teams]

# Create dictionary for round two matchups, same format as round one, but the values are lists of the two possible opponents they could face in round two
values = [0] * len(teams)
for i in range(len(teams)):
    if i % 4 < 2:
        values[i] = [teams[4*floor(i/4)+j] for j in range(2,4)]
    else:
        values[i] = [teams[4*ceil(i/4)-j] for j in range(4,2, -1)]

secondround = dict(zip(teams, values))

# Put second round probabilities in
results['Second Round'] = [sum(df.loc[i, j]*results.loc[j, 'First Round']*results.loc[i, 'First Round'] for j in secondround[i]) for i in teams ]

# Create dictionary for round three matchups, same format as round two
values = [0] * len(teams)
for i in range(len(teams)):
    if i % 8 < 4:
        values[i] = [teams[8*floor(i/8)+j] for j in range(4,8)]
    else:
        values[i] = [teams[8*ceil(i/8)-j] for j in range(8,4, -1)]


thirdround = dict(zip(teams, values))

# Put third round probabilities in
results['Third Round'] = [sum(df.loc[i, j]*results.loc[j, 'Second Round']*results.loc[i, 'Second Round'] for j in thirdround[i]) for i in teams]

# Create dictionary for round four matchups, same format as round three
values = [0] * len(teams)
for i in range(len(teams)):
    if i % 16 < 8:
        values[i] = [teams[16*floor(i/16)+j] for j in range(8,16)]
    else:
        values[i] = [teams[16*ceil(i/16)-j] for j in range(16,8, -1)]
        
fourthround = dict(zip(teams, values))

# Put fourth round probabilities in
results['Fourth Round'] = [sum(df.loc[i, j]*results.loc[j, 'Third Round']*results.loc[i, 'Third Round'] for j in fourthround[i]) for i in teams]

# Create dictionary for round five matchups, same format as round four
values = [0] * len(teams)
for i in range(len(teams)):
    if i % 32 < 16:
        values[i] = [teams[32*floor(i/32)+j] for j in range(16,32)]
    else:
        values[i] = [teams[32*ceil(i/32)-j] for j in range(32,16, -1)]

fifthround = dict(zip(teams, values))

# Put fifth round probabilities in
results['Fifth Round'] = [sum(df.loc[i, j]*results.loc[j, 'Fourth Round']*results.loc[i, 'Fourth Round'] for j in fifthround[i]) for i in teams]

# Create dictionary for round six matchups, same format as round five
values = [0] * len(teams)
for i in range(len(teams)):
    if i % 64 < 32:
        values[i] = [teams[64*floor(i/64)+j] for j in range(32,64)]
    else:
        values[i] = [teams[64*ceil(i/64)-j] for j in range(64,32, -1)]


sixthround = dict(zip(teams, values))

# Put sixth round probabilities in
results['Sixth Round'] = [sum(df.loc[i, j]*results.loc[j, 'Fifth Round']*results.loc[i, 'Fifth Round'] for j in sixthround[i]) for i in teams]



# Create model and Indices
m = Model("March Madness")
rounds = results.columns.tolist()
weights = {'First Round' : 1, 'Second Round' : 2, 'Third Round' :4, 'Fourth Round' : 8, 'Fifth Round' : 16, 'Sixth Round' : 32}

# Create decision variables
x = m.addVars(teams, rounds, vtype = GRB.BINARY, name = 'x')

# Create objective function
m.setObjective(quicksum(weights[k] * x[i, k] * results.loc[i, k] for i in teams for k in rounds), GRB.MAXIMIZE)


# Create constraints

# Round 1 Constraints
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Duke', 'N Dakota St']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['VA Commonwealth', 'UCF']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Mississippi St', 'Liberty']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Virginia Tech', 'St Louis']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Maryland', 'Belmont']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['LSU', 'Yale']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Louisville', 'Minnesota']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Michigan St', 'Bradley']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Gonzaga', 'F Dickinson']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Syracuse', 'Baylor']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Marquette', 'Murray St']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Florida St', 'Vermont']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Buffalo', 'Arizona St']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Texas Tech', 'N Kentucky']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Nevada', 'Florida']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Michigan', 'Montana']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Virginia', 'Gardner Webb']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Mississippi', 'Oklahoma']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Wisconsin', 'Oregon']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Kansas St', 'UC Irvine']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Villanova', "St Mary's CA"]) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Purdue', 'Old Dominion']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Cincinnati', 'Iowa']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Tennessee', 'Colgate']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['North Carolina', 'Iona']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Utah St', 'Washington']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Auburn', 'New Mexico St']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Kansas', 'Northeastern']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Iowa St', 'Ohio St']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Houston', 'Georgia St']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Wofford', 'Seton Hall']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Kentucky', 'Abilene Chr']) == 1)

# Round 2 Constraints
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Duke', 'N Dakota St', 'VA Commonwealth', 'UCF']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Mississippi St', 'Liberty', 'Virginia Tech', 'St Louis']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Maryland', 'Belmont', 'LSU', 'Yale']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Louisville', 'Minnesota', 'Michigan St', 'Bradley']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Gonzaga', 'F Dickinson', 'Syracuse', 'Baylor']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Marquette', 'Murray St', 'Florida St', 'Vermont']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Buffalo', 'Arizona St', 'Texas Tech', 'N Kentucky']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Nevada', 'Florida', 'Michigan', 'Montana']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Virginia', 'Gardner Webb', 'Mississippi', 'Oklahoma']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Wisconsin', 'Oregon', 'Kansas St', 'UC Irvine']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Villanova', "St Mary's CA", 'Purdue', 'Old Dominion']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Cincinnati', 'Iowa', 'Tennessee', 'Colgate']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['North Carolina', 'Iona', 'Utah St', 'Washington']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Auburn', 'New Mexico St', 'Kansas', 'Northeastern']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Iowa St', 'Ohio St', 'Houston', 'Georgia St']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Wofford', 'Seton Hall', 'Kentucky', 'Abilene Chr']) == 1)

# Round 3 Constraints
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['Duke', 'N Dakota St', 'VA Commonwealth', 'UCF', 'Mississippi St', 'Liberty', 'Virginia Tech', 'St Louis']) == 1)
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['Maryland', 'Belmont', 'LSU', 'Yale', 'Louisville', 'Minnesota', 'Michigan St', 'Bradley']) == 1)
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['Gonzaga', 'F Dickinson', 'Syracuse', 'Baylor', 'Marquette', 'Murray St', 'Florida St', 'Vermont']) == 1)
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['Buffalo', 'Arizona St', 'Texas Tech', 'N Kentucky', 'Nevada', 'Florida', 'Michigan', 'Montana']) == 1)
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['Virginia', 'Gardner Webb', 'Mississippi', 'Oklahoma', 'Wisconsin', 'Oregon', 'Kansas St', 'UC Irvine']) == 1)
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['Villanova', "St Mary's CA", 'Purdue', 'Old Dominion', 'Cincinnati', 'Iowa', 'Tennessee', 'Colgate']) == 1)
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['North Carolina', 'Iona', 'Utah St', 'Washington', 'Auburn', 'New Mexico St', 'Kansas', 'Northeastern']) == 1)
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['Iowa St', 'Ohio St', 'Houston', 'Georgia St', 'Wofford', 'Seton Hall', 'Kentucky', 'Abilene Chr']) == 1)

# Round 4 Constraints
m.addConstr(quicksum(x[i, 'Fourth Round'] for i in teams[0:16]) == 1)
m.addConstr(quicksum(x[i, 'Fourth Round'] for i in teams[16:32]) == 1)
m.addConstr(quicksum(x[i, 'Fourth Round'] for i in teams[32:48]) == 1)
m.addConstr(quicksum(x[i, 'Fourth Round'] for i in teams[48:64]) == 1)

# Round 5 Constraints
m.addConstr(quicksum(x[i, 'Fifth Round'] for i in teams[0:32]) == 1)
m.addConstr(quicksum(x[i, 'Fifth Round'] for i in teams[32:64]) == 1)

# Round 6 Constraints
m.addConstr(quicksum(x[i, 'Sixth Round'] for i in teams) == 1)

# Elimination Constraints
m.addConstrs(quicksum(x[i, k] for k in rounds[1:6]) <= 5*x[i, "First Round"] for i in teams)
m.addConstrs(quicksum(x[i, k] for k in rounds[2:6]) <= 4*x[i, "Second Round"] for i in teams)
m.addConstrs(quicksum(x[i, k] for k in rounds[3:6]) <= 3*x[i, "Third Round"] for i in teams)
m.addConstrs(quicksum(x[i, k] for k in rounds[4:6]) <= 2*x[i, "Fourth Round"] for i in teams)
m.addConstrs(quicksum(x[i, k] for k in rounds[5:6]) <= x[i, "Fifth Round"] for i in teams)

# Upset Constraints
m.addConstr(quicksum(x[i, 'First Round'] for i in teams[3::16]) >= 2)
m.addConstr(quicksum(x[i, 'First Round'] for i in teams[5::16]) >= 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in teams[9::16]) >= 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in teams[13::16]) >= 1)



# Optimize and record objective value
m.optimize()
objectiveScores = []
objectiveScores.append(m.ObjVal)

# Setup decision variable results from optimization in dataframe
resultsx = []
for v in m.getVars():
    #print("%s %g" % (v.varName, v.x))
    resultsx.append(v.x)
reshapedresultsx = [resultsx[i:i+6] for i in range(0, 384, 6)]
resultsDF = pd.DataFrame(reshapedresultsx, index = teams, columns=rounds)

#Compute bracket score based on how it matches 2019 bracket
bracketScores = []
bracketScore = 0
for i in teams:
    k = 0
    for j in rounds:
        if resultsDF.loc[i, j] == origninalBracket.loc[i, j] and origninalBracket.loc[i,j] == 1:
            bracketScore = bracketScore + 2**k
        k+=1
bracketScores.append(bracketScore)



# Repeat 9 more times 
for a in range(9):

    # Create new constraint forcing out a winning game to get a new bracket
    winningGames = [[i, j] for i in teams for j in rounds if resultsDF.loc[i, j] == 1]
    m.addConstr(quicksum(x[i, j] for [i, j] in winningGames) <= 62)

    # Optimize model with new constraint and record value
    m.optimize()
    objectiveScores.append(m.ObjVal)

    # Setup results from optimization in dataframe
    resultsx = []
    for v in m.getVars():
        #print("%s %g" % (v.varName, v.x))
        resultsx.append(v.x)
    reshapedresultsx = [resultsx[i:i+6] for i in range(0, 384, 6)]
    resultsDF = pd.DataFrame(reshapedresultsx, index = teams, columns=rounds)

    # Compute bracket score based on how it matches 2019 bracket
    bracketScore = 0
    for i in teams:
        k = 0
        for j in rounds:
            if resultsDF.loc[i, j] == origninalBracket.loc[i, j] and origninalBracket.loc[i,j] == 1:
                bracketScore = bracketScore + 2**k
            k+=1
    bracketScores.append(bracketScore)
    
# Print results
print(bracketScores)
print(objectiveScores)
# Out:
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 387 rows, 384 columns and 1680 nonzeros
# Model fingerprint: 0xa388a19e
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Found heuristic solution: objective 37.5775295
# Presolve removed 48 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 339 rows, 336 columns, 1616 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.689139e+01, 50 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   96.89139    0    2   37.57753   96.89139   158%     -    0s
# H    0     0                      96.7758683   96.89139  0.12%     -    0s
#      0     0   96.89139    0    2   96.77587   96.89139  0.12%     -    0s
#
# Explored 1 nodes (50 simplex iterations) in 0.01 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 96.7759 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.677586832162e+01, best bound 9.677586832162e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 388 rows, 384 columns and 1743 nonzeros
# Model fingerprint: 0xecb52432
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R387 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 48 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 340 rows, 336 columns, 1675 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.688843e+01, 49 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   96.88843    0    2   37.57753   96.88843   158%     -    0s
# H    0     0                      96.6013310   96.88843  0.30%     -    0s
# H    0     0                      96.7454683   96.88843  0.15%     -    0s
# *    0     0               0      96.7471280   96.74713  0.00%     -    0s
#
# Explored 1 nodes (51 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 96.7471 96.7455 96.6013 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.674712804157e+01, best bound 9.674712804157e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 389 rows, 384 columns and 1806 nonzeros
# Model fingerprint: 0x8d80e3a8
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R388 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 48 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 341 rows, 336 columns, 1734 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.688843e+01, 54 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   96.88843    0    2   37.57753   96.88843   158%     -    0s
# H    0     0                      96.6013310   96.88843  0.30%     -    0s
#      0     0   96.74630    0    4   96.60133   96.74630  0.15%     -    0s
# H    0     1                      96.7454683   96.74630  0.00%     -    0s
#
# Cutting planes:
#   Cover: 2
#
# Explored 1 nodes (57 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 96.7455 96.6013 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.674546832162e+01, best bound 9.674546832162e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 390 rows, 384 columns and 1869 nonzeros
# Model fingerprint: 0x6edf311d
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R389 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 48 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 342 rows, 336 columns, 1793 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.688843e+01, 54 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   96.88843    0    2   37.57753   96.88843   158%     -    0s
# H    0     0                      96.6013310   96.88843  0.30%     -    0s
#      0     0   96.74630    0    4   96.60133   96.74630  0.15%     -    0s
#      0     0   96.73647    0    4   96.60133   96.73647  0.14%     -    0s
# H    0     0                      96.6790683   96.73647  0.06%     -    0s
# H    0     0                      96.7344683   96.73647  0.00%     -    0s
#      0     0   96.73647    0    4   96.73447   96.73647  0.00%     -    0s
#
# Explored 1 nodes (59 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 96.7345 96.6791 96.6013 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.673446832162e+01, best bound 9.673446832162e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 391 rows, 384 columns and 1932 nonzeros
# Model fingerprint: 0x8c09b087
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R390 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 50 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 341 rows, 336 columns, 1733 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.688843e+01, 51 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   96.88843    0    2   37.57753   96.88843   158%     -    0s
# H    0     0                      96.6013310   96.88843  0.30%     -    0s
# H    0     0                      96.6906683   96.88843  0.20%     -    0s
#      0     0   96.73730    0    4   96.69067   96.73730  0.05%     -    0s
# *    0     0               0      96.7167280   96.71673  0.00%     -    0s
#
# Explored 1 nodes (55 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 96.7167 96.6907 96.6013 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.671672804157e+01, best bound 9.671672804157e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 392 rows, 384 columns and 1995 nonzeros
# Model fingerprint: 0x55c99db3
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R391 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 50 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 342 rows, 336 columns, 1792 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.688843e+01, 51 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   96.88843    0    2   37.57753   96.88843   158%     -    0s
# H    0     0                      96.6013310   96.88843  0.30%     -    0s
#      0     0   96.73730    0    4   96.60133   96.73730  0.14%     -    0s
#      0     0   96.72747    0    2   96.60133   96.72747  0.13%     -    0s
# H    0     0                      96.6790683   96.72747  0.05%     -    0s
# H    0     0                      96.7057280   96.72747  0.02%     -    0s
#      0     0   96.72747    0    2   96.70573   96.72747  0.02%     -    0s
#
# Explored 1 nodes (56 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 96.7057 96.6791 96.6013 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.670572804157e+01, best bound 9.670572804157e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 393 rows, 384 columns and 2058 nonzeros
# Model fingerprint: 0x1457d470
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R392 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 52 rows and 48 columns
# Presolve time: 0.01s
# Presolved: 341 rows, 336 columns, 1732 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.688843e+01, 51 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   96.88843    0    2   37.57753   96.88843   158%     -    0s
# H    0     0                      96.6013310   96.88843  0.30%     -    0s
#      0     0   96.73730    0    4   96.60133   96.73730  0.14%     -    0s
# H    0     0                      96.6906683   96.73730  0.05%     -    0s
#
# Explored 1 nodes (54 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 96.6907 96.6013 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.669066832162e+01, best bound 9.669066832162e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 394 rows, 384 columns and 2121 nonzeros
# Model fingerprint: 0x4f99445a
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R393 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 52 rows and 48 columns
# Presolve time: 0.01s
# Presolved: 342 rows, 336 columns, 1791 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.688843e+01, 51 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   96.88843    0    2   37.57753   96.88843   158%     -    0s
# H    0     0                      96.6013310   96.88843  0.30%     -    0s
#      0     0   96.73730    0    4   96.60133   96.73730  0.14%     -    0s
#      0     0   96.72747    0    2   96.60133   96.72747  0.13%     -    0s
# H    0     0                      96.6790683   96.72747  0.05%     -    0s
# H    0     0                      96.6846683   96.72747  0.04%     -    0s
#
# Cutting planes:
#   Zero half: 1
#
# Explored 1 nodes (55 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 96.6847 96.6791 96.6013 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.668466832162e+01, best bound 9.668466832162e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 395 rows, 384 columns and 2184 nonzeros
# Model fingerprint: 0x51abb427
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R394 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 52 rows and 48 columns
# Presolve time: 0.01s
# Presolved: 343 rows, 336 columns, 1850 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.688843e+01, 49 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   96.88843    0    2   37.57753   96.88843   158%     -    0s
# H    0     0                      96.6013310   96.88843  0.30%     -    0s
#      0     0   96.73730    0    4   96.60133   96.73730  0.14%     -    0s
#      0     0   96.72747    0    2   96.60133   96.72747  0.13%     -    0s
# H    0     0                      96.6790683   96.72747  0.05%     -    0s
# H    0     0                      96.6796683   96.72747  0.05%     -    0s
#      0     0 infeasible    0        96.67967   96.67967  0.00%     -    0s
#
# Cutting planes:
#   Zero half: 1
#
# Explored 1 nodes (57 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 96.6797 96.6791 96.6013 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.667966832162e+01, best bound 9.667966832162e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 396 rows, 384 columns and 2247 nonzeros
# Model fingerprint: 0x0333e718
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R395 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 53 rows and 48 columns
# Presolve time: 0.01s
# Presolved: 343 rows, 336 columns, 1849 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.688843e+01, 49 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   96.88843    0    2   37.57753   96.88843   158%     -    0s
# H    0     0                      96.6013310   96.88843  0.30%     -    0s
#      0     0   96.73730    0    4   96.60133   96.73730  0.14%     -    0s
#      0     0   96.72747    0    2   96.60133   96.72747  0.13%     -    0s
# H    0     0                      96.6790683   96.72747  0.05%     -    0s
#      0     0     cutoff    0        96.67907   96.67907  0.00%     -    0s
#
# Cutting planes:
#   Zero half: 2
#
# Explored 1 nodes (57 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 96.6791 96.6013 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.667906832162e+01, best bound 9.667906832162e+01, gap 0.0000%
# [81, 81, 81, 82, 81, 82, 79, 81, 80, 81]
# [96.77586832161673, 96.74712804157495, 96.74546832161673, 96.73446832161673, 96.71672804157495, 96.70572804157496, 96.69066832161671, 96.68466832161671, 96.67966832161672, 96.67906832161674]

# %%
# Upper Seed Constraints

from re import T
import pandas as pd
import requests
import io
from math import *
from gurobipy import *
import matplotlib.pyplot as plt

# Pull in initial CSV file from Github and transform it into a Dataframe

url = "https://raw.githubusercontent.com/camjm21/4133project/main/March%20Madness.csv"
download = requests.get(url).content
df = pd.read_csv(io.StringIO(download.decode('utf-8')))
df.set_index('TEAM', inplace=True)

#Pull in actual 2019 bracket results
url2 = "https://raw.githubusercontent.com/camjm21/4133project/main/2019ActualBracket.csv"
download2 = requests.get(url2).content
origninalBracket = pd.read_csv(io.StringIO(download2.decode('utf-8')))
origninalBracket.rename(columns = {"Unnamed: 0": "TEAM"}, inplace = True)
origninalBracket.set_index('TEAM', inplace = True)


# Create dictionary for round one matchups, every team will be a key, with their opponent being the value
teams = list(df.index)
values = [0] * len(teams)
for i in range(len(teams)):
    if i % 2 == 0:
        values[i+1] = teams[i]
    else:
        values[i-1] = teams[i]

firstround = dict(zip(teams, values))

# Create dataframe to put results in
results = pd.DataFrame(index=teams,columns=['First Round','Second Round', 'Third Round', 'Fourth Round', 'Fifth Round', 'Sixth Round'])

# Put first round probabilities in
results['First Round'] = [df.loc[i, firstround[i]] for i in teams]

# Create dictionary for round two matchups, same format as round one, but the values are lists of the two possible opponents they could face in round two
values = [0] * len(teams)
for i in range(len(teams)):
    if i % 4 < 2:
        values[i] = [teams[4*floor(i/4)+j] for j in range(2,4)]
    else:
        values[i] = [teams[4*ceil(i/4)-j] for j in range(4,2, -1)]

secondround = dict(zip(teams, values))

# Put second round probabilities in
results['Second Round'] = [sum(df.loc[i, j]*results.loc[j, 'First Round']*results.loc[i, 'First Round'] for j in secondround[i]) for i in teams ]

# Create dictionary for round three matchups, same format as round two
values = [0] * len(teams)
for i in range(len(teams)):
    if i % 8 < 4:
        values[i] = [teams[8*floor(i/8)+j] for j in range(4,8)]
    else:
        values[i] = [teams[8*ceil(i/8)-j] for j in range(8,4, -1)]


thirdround = dict(zip(teams, values))

# Put third round probabilities in
results['Third Round'] = [sum(df.loc[i, j]*results.loc[j, 'Second Round']*results.loc[i, 'Second Round'] for j in thirdround[i]) for i in teams]

# Create dictionary for round four matchups, same format as round three
values = [0] * len(teams)
for i in range(len(teams)):
    if i % 16 < 8:
        values[i] = [teams[16*floor(i/16)+j] for j in range(8,16)]
    else:
        values[i] = [teams[16*ceil(i/16)-j] for j in range(16,8, -1)]
        
fourthround = dict(zip(teams, values))

# Put fourth round probabilities in
results['Fourth Round'] = [sum(df.loc[i, j]*results.loc[j, 'Third Round']*results.loc[i, 'Third Round'] for j in fourthround[i]) for i in teams]

# Create dictionary for round five matchups, same format as round four
values = [0] * len(teams)
for i in range(len(teams)):
    if i % 32 < 16:
        values[i] = [teams[32*floor(i/32)+j] for j in range(16,32)]
    else:
        values[i] = [teams[32*ceil(i/32)-j] for j in range(32,16, -1)]

fifthround = dict(zip(teams, values))

# Put fifth round probabilities in
results['Fifth Round'] = [sum(df.loc[i, j]*results.loc[j, 'Fourth Round']*results.loc[i, 'Fourth Round'] for j in fifthround[i]) for i in teams]

# Create dictionary for round six matchups, same format as round five
values = [0] * len(teams)
for i in range(len(teams)):
    if i % 64 < 32:
        values[i] = [teams[64*floor(i/64)+j] for j in range(32,64)]
    else:
        values[i] = [teams[64*ceil(i/64)-j] for j in range(64,32, -1)]


sixthround = dict(zip(teams, values))

# Put sixth round probabilities in
results['Sixth Round'] = [sum(df.loc[i, j]*results.loc[j, 'Fifth Round']*results.loc[i, 'Fifth Round'] for j in sixthround[i]) for i in teams]



# Create model and Indices
m = Model("March Madness")
rounds = results.columns.tolist()
weights = {'First Round' : 1, 'Second Round' : 2, 'Third Round' :4, 'Fourth Round' : 8, 'Fifth Round' : 16, 'Sixth Round' : 32}

# Create decision variables
x = m.addVars(teams, rounds, vtype = GRB.BINARY, name = 'x')

# Create objective function
m.setObjective(quicksum(weights[k] * x[i, k] * results.loc[i, k] for i in teams for k in rounds), GRB.MAXIMIZE)


# Create constraints

# Round 1 Constraints
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Duke', 'N Dakota St']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['VA Commonwealth', 'UCF']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Mississippi St', 'Liberty']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Virginia Tech', 'St Louis']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Maryland', 'Belmont']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['LSU', 'Yale']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Louisville', 'Minnesota']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Michigan St', 'Bradley']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Gonzaga', 'F Dickinson']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Syracuse', 'Baylor']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Marquette', 'Murray St']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Florida St', 'Vermont']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Buffalo', 'Arizona St']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Texas Tech', 'N Kentucky']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Nevada', 'Florida']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Michigan', 'Montana']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Virginia', 'Gardner Webb']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Mississippi', 'Oklahoma']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Wisconsin', 'Oregon']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Kansas St', 'UC Irvine']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Villanova', "St Mary's CA"]) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Purdue', 'Old Dominion']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Cincinnati', 'Iowa']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Tennessee', 'Colgate']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['North Carolina', 'Iona']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Utah St', 'Washington']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Auburn', 'New Mexico St']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Kansas', 'Northeastern']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Iowa St', 'Ohio St']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Houston', 'Georgia St']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Wofford', 'Seton Hall']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Kentucky', 'Abilene Chr']) == 1)

# Round 2 Constraints
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Duke', 'N Dakota St', 'VA Commonwealth', 'UCF']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Mississippi St', 'Liberty', 'Virginia Tech', 'St Louis']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Maryland', 'Belmont', 'LSU', 'Yale']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Louisville', 'Minnesota', 'Michigan St', 'Bradley']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Gonzaga', 'F Dickinson', 'Syracuse', 'Baylor']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Marquette', 'Murray St', 'Florida St', 'Vermont']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Buffalo', 'Arizona St', 'Texas Tech', 'N Kentucky']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Nevada', 'Florida', 'Michigan', 'Montana']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Virginia', 'Gardner Webb', 'Mississippi', 'Oklahoma']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Wisconsin', 'Oregon', 'Kansas St', 'UC Irvine']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Villanova', "St Mary's CA", 'Purdue', 'Old Dominion']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Cincinnati', 'Iowa', 'Tennessee', 'Colgate']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['North Carolina', 'Iona', 'Utah St', 'Washington']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Auburn', 'New Mexico St', 'Kansas', 'Northeastern']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Iowa St', 'Ohio St', 'Houston', 'Georgia St']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Wofford', 'Seton Hall', 'Kentucky', 'Abilene Chr']) == 1)

# Round 3 Constraints
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['Duke', 'N Dakota St', 'VA Commonwealth', 'UCF', 'Mississippi St', 'Liberty', 'Virginia Tech', 'St Louis']) == 1)
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['Maryland', 'Belmont', 'LSU', 'Yale', 'Louisville', 'Minnesota', 'Michigan St', 'Bradley']) == 1)
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['Gonzaga', 'F Dickinson', 'Syracuse', 'Baylor', 'Marquette', 'Murray St', 'Florida St', 'Vermont']) == 1)
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['Buffalo', 'Arizona St', 'Texas Tech', 'N Kentucky', 'Nevada', 'Florida', 'Michigan', 'Montana']) == 1)
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['Virginia', 'Gardner Webb', 'Mississippi', 'Oklahoma', 'Wisconsin', 'Oregon', 'Kansas St', 'UC Irvine']) == 1)
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['Villanova', "St Mary's CA", 'Purdue', 'Old Dominion', 'Cincinnati', 'Iowa', 'Tennessee', 'Colgate']) == 1)
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['North Carolina', 'Iona', 'Utah St', 'Washington', 'Auburn', 'New Mexico St', 'Kansas', 'Northeastern']) == 1)
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['Iowa St', 'Ohio St', 'Houston', 'Georgia St', 'Wofford', 'Seton Hall', 'Kentucky', 'Abilene Chr']) == 1)

# Round 4 Constraints
m.addConstr(quicksum(x[i, 'Fourth Round'] for i in teams[0:16]) == 1)
m.addConstr(quicksum(x[i, 'Fourth Round'] for i in teams[16:32]) == 1)
m.addConstr(quicksum(x[i, 'Fourth Round'] for i in teams[32:48]) == 1)
m.addConstr(quicksum(x[i, 'Fourth Round'] for i in teams[48:64]) == 1)

# Round 5 Constraints
m.addConstr(quicksum(x[i, 'Fifth Round'] for i in teams[0:32]) == 1)
m.addConstr(quicksum(x[i, 'Fifth Round'] for i in teams[32:64]) == 1)

# Round 6 Constraints
m.addConstr(quicksum(x[i, 'Sixth Round'] for i in teams) == 1)

# Elimination Constraints
m.addConstrs(quicksum(x[i, k] for k in rounds[1:6]) <= 5*x[i, "First Round"] for i in teams)
m.addConstrs(quicksum(x[i, k] for k in rounds[2:6]) <= 4*x[i, "Second Round"] for i in teams)
m.addConstrs(quicksum(x[i, k] for k in rounds[3:6]) <= 3*x[i, "Third Round"] for i in teams)
m.addConstrs(quicksum(x[i, k] for k in rounds[4:6]) <= 2*x[i, "Fourth Round"] for i in teams)
m.addConstrs(quicksum(x[i, k] for k in rounds[5:6]) <= x[i, "Fifth Round"] for i in teams)

# Upper Seed Constraints
m.addConstr(quicksum(x[i, 'Fourth Round'] for i in teams[0::16]) <= 3)
#m.addConstr(quicksum(x[i, 'Fourth Round'] for i in (teams[0::16] + teams[13::16])) >= 2)


# Optimize and record objective value
m.optimize()
objectiveScores = []
objectiveScores.append(m.ObjVal)

# Setup decision variable results from optimization in dataframe
resultsx = []
for v in m.getVars():
    #print("%s %g" % (v.varName, v.x))
    resultsx.append(v.x)
reshapedresultsx = [resultsx[i:i+6] for i in range(0, 384, 6)]
resultsDF = pd.DataFrame(reshapedresultsx, index = teams, columns=rounds)

#Compute bracket score based on how it matches 2019 bracket
bracketScores = []
bracketScore = 0
for i in teams:
    k = 0
    for j in rounds:
        if resultsDF.loc[i, j] == origninalBracket.loc[i, j] and origninalBracket.loc[i,j] == 1:
            bracketScore = bracketScore + 2**k
        k+=1
bracketScores.append(bracketScore)



# Repeat 9 more times 
for a in range(9):

    # Create new constraint forcing out a winning game to get a new bracket
    winningGames = [[i, j] for i in teams for j in rounds if resultsDF.loc[i, j] == 1]
    m.addConstr(quicksum(x[i, j] for [i, j] in winningGames) <= 62)

    # Optimize model with new constraint and record value
    m.optimize()
    objectiveScores.append(m.ObjVal)

    # Setup results from optimization in dataframe
    resultsx = []
    for v in m.getVars():
        #print("%s %g" % (v.varName, v.x))
        resultsx.append(v.x)
    reshapedresultsx = [resultsx[i:i+6] for i in range(0, 384, 6)]
    resultsDF = pd.DataFrame(reshapedresultsx, index = teams, columns=rounds)

    # Compute bracket score based on how it matches 2019 bracket
    bracketScore = 0
    for i in teams:
        k = 0
        for j in rounds:
            if resultsDF.loc[i, j] == origninalBracket.loc[i, j] and origninalBracket.loc[i,j] == 1:
                bracketScore = bracketScore + 2**k
            k+=1
    bracketScores.append(bracketScore)
    
# Print results
print(bracketScores)
print(objectiveScores)
# Out:
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 384 rows, 384 columns and 1668 nonzeros
# Model fingerprint: 0xd2656b78
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 37.5775295
# Presolve removed 48 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 336 rows, 336 columns, 1604 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.611787e+01, 41 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      96.1178699   96.11787  0.00%     -    0s
#
# Explored 0 nodes (41 simplex iterations) in 0.01 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 96.1179 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.611786994566e+01, best bound 9.611786994566e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 385 rows, 384 columns and 1731 nonzeros
# Model fingerprint: 0x4907db54
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R384 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 48 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 337 rows, 336 columns, 1666 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.610687e+01, 50 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      96.1068699   96.10687  0.00%     -    0s
#
# Explored 0 nodes (50 simplex iterations) in 0.01 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 96.1069 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.610686994566e+01, best bound 9.610686994566e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 386 rows, 384 columns and 1794 nonzeros
# Model fingerprint: 0xaa7ce614
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R385 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 49 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 337 rows, 336 columns, 1665 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.609327e+01, 50 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      96.0932699   96.09327  0.00%     -    0s
#
# Explored 0 nodes (50 simplex iterations) in 0.01 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 96.0933 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.609326994566e+01, best bound 9.609326994566e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 387 rows, 384 columns and 1857 nonzeros
# Model fingerprint: 0x768b98ac
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R386 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 49 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 338 rows, 336 columns, 1726 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.608913e+01, 53 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      96.0891297   96.08913  0.00%     -    0s
#
# Explored 0 nodes (53 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 96.0891 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.608912966562e+01, best bound 9.608912966562e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 388 rows, 384 columns and 1920 nonzeros
# Model fingerprint: 0x17d582fa
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R387 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 49 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 339 rows, 336 columns, 1788 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.608820e+01, 54 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   96.08820    0    3   37.57753   96.08820   156%     -    0s
# H    0     0                      95.9564699   96.08820  0.14%     -    0s
# H    0     0                      96.0822699   96.08820  0.01%     -    0s
#
# Explored 1 nodes (54 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 96.0823 95.9565 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.608226994566e+01, best bound 9.608819980564e+01, gap 0.0062%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 389 rows, 384 columns and 1983 nonzeros
# Model fingerprint: 0xe59105fc
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R388 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 51 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 338 rows, 336 columns, 1726 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.608820e+01, 53 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   96.08820    0    3   37.57753   96.08820   156%     -    0s
# H    0     0                      95.9564699   96.08820  0.14%     -    0s
# H    0     0                      96.0872699   96.08820  0.00%     -    0s
#
# Explored 1 nodes (53 simplex iterations) in 0.01 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 96.0873 95.9565 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.608726994566e+01, best bound 9.608819980564e+01, gap 0.0010%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 390 rows, 384 columns and 2046 nonzeros
# Model fingerprint: 0x598c74eb
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R389 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 50 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 340 rows, 336 columns, 1849 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.609800e+01, 55 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   96.09800    0    3   37.57753   96.09800   156%     -    0s
# H    0     0                      96.0764699   96.09800  0.02%     -    0s
# H    0     0                      96.0781297   96.09800  0.02%     -    0s
#      0     0   96.09120    0    3   96.07813   96.09120  0.01%     -    0s
#
# Cutting planes:
#   RLT: 1
#
# Explored 1 nodes (57 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 96.0781 96.0765 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.607812966562e+01, best bound 9.607812966562e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 391 rows, 384 columns and 2109 nonzeros
# Model fingerprint: 0xbf0a8690
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R390 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 51 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 340 rows, 336 columns, 1848 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.609642e+01, 56 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   96.09642    0    4   37.57753   96.09642   156%     -    0s
# H    0     0                      95.9564699   96.09642  0.15%     -    0s
# H    0     0                      96.0764699   96.09642  0.02%     -    0s
#      0     0     cutoff    0        96.07647   96.07647  0.00%     -    0s
#
# Cutting planes:
#   Zero half: 1
#   RLT: 1
#
# Explored 1 nodes (58 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 96.0765 95.9565 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.607646994566e+01, best bound 9.607646994566e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 392 rows, 384 columns and 2172 nonzeros
# Model fingerprint: 0x358523bd
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R391 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 51 rows and 48 columns
# Presolve time: 0.01s
# Presolved: 341 rows, 336 columns, 1909 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.609642e+01, 56 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   96.09642    0    4   37.57753   96.09642   156%     -    0s
# H    0     0                      95.9564699   96.09642  0.15%     -    0s
# H    0     0                      96.0762699   96.09642  0.02%     -    0s
#      0     0     cutoff    0        96.07627   96.07627  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 2
#
# Explored 1 nodes (57 simplex iterations) in 0.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 96.0763 95.9565 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.607626994566e+01, best bound 9.607626994566e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 393 rows, 384 columns and 2235 nonzeros
# Model fingerprint: 0xc67e4268
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R392 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 52 rows and 48 columns
# Presolve time: 0.01s
# Presolved: 341 rows, 336 columns, 1909 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.609903e+01, 55 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   96.09903    0    4   37.57753   96.09903   156%     -    0s
# H    0     0                      95.9564699   96.09903  0.15%     -    0s
# H    0     0                      96.0626699   96.09903  0.04%     -    0s
# H    0     0                      96.0654699   96.09903  0.03%     -    0s
#      0     0   96.08820    0    3   96.06547   96.08820  0.02%     -    0s
#      0     0   96.08820    0    3   96.06547   96.08820  0.02%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   MIR: 1
#
# Explored 1 nodes (60 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 96.0655 96.0627 95.9565 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.606546994566e+01, best bound 9.606952966562e+01, gap 0.0042%
# [86, 87, 87, 86, 88, 87, 87, 87, 88, 88]
# [96.11786994566013, 96.10686994566014, 96.09326994566013, 96.08912966561836, 96.08226994566013, 96.08726994566013, 96.07812966561836, 96.07646994566014, 96.07626994566013, 96.06546994566014]

# %%
# Upset and Upper Seed Constraints

from re import T
import pandas as pd
import requests
import io
from math import *
from gurobipy import *
import matplotlib.pyplot as plt

# Pull in initial CSV file from Github and transform it into a Dataframe

url = "https://raw.githubusercontent.com/camjm21/4133project/main/March%20Madness.csv"
download = requests.get(url).content
df = pd.read_csv(io.StringIO(download.decode('utf-8')))
df.set_index('TEAM', inplace=True)

#Pull in actual 2019 bracket results
url2 = "https://raw.githubusercontent.com/camjm21/4133project/main/2019ActualBracket.csv"
download2 = requests.get(url2).content
origninalBracket = pd.read_csv(io.StringIO(download2.decode('utf-8')))
origninalBracket.rename(columns = {"Unnamed: 0": "TEAM"}, inplace = True)
origninalBracket.set_index('TEAM', inplace = True)


# Create dictionary for round one matchups, every team will be a key, with their opponent being the value
teams = list(df.index)
values = [0] * len(teams)
for i in range(len(teams)):
    if i % 2 == 0:
        values[i+1] = teams[i]
    else:
        values[i-1] = teams[i]

firstround = dict(zip(teams, values))

# Create dataframe to put results in
results = pd.DataFrame(index=teams,columns=['First Round','Second Round', 'Third Round', 'Fourth Round', 'Fifth Round', 'Sixth Round'])

# Put first round probabilities in
results['First Round'] = [df.loc[i, firstround[i]] for i in teams]

# Create dictionary for round two matchups, same format as round one, but the values are lists of the two possible opponents they could face in round two
values = [0] * len(teams)
for i in range(len(teams)):
    if i % 4 < 2:
        values[i] = [teams[4*floor(i/4)+j] for j in range(2,4)]
    else:
        values[i] = [teams[4*ceil(i/4)-j] for j in range(4,2, -1)]

secondround = dict(zip(teams, values))

# Put second round probabilities in
results['Second Round'] = [sum(df.loc[i, j]*results.loc[j, 'First Round']*results.loc[i, 'First Round'] for j in secondround[i]) for i in teams ]

# Create dictionary for round three matchups, same format as round two
values = [0] * len(teams)
for i in range(len(teams)):
    if i % 8 < 4:
        values[i] = [teams[8*floor(i/8)+j] for j in range(4,8)]
    else:
        values[i] = [teams[8*ceil(i/8)-j] for j in range(8,4, -1)]


thirdround = dict(zip(teams, values))

# Put third round probabilities in
results['Third Round'] = [sum(df.loc[i, j]*results.loc[j, 'Second Round']*results.loc[i, 'Second Round'] for j in thirdround[i]) for i in teams]

# Create dictionary for round four matchups, same format as round three
values = [0] * len(teams)
for i in range(len(teams)):
    if i % 16 < 8:
        values[i] = [teams[16*floor(i/16)+j] for j in range(8,16)]
    else:
        values[i] = [teams[16*ceil(i/16)-j] for j in range(16,8, -1)]
        
fourthround = dict(zip(teams, values))

# Put fourth round probabilities in
results['Fourth Round'] = [sum(df.loc[i, j]*results.loc[j, 'Third Round']*results.loc[i, 'Third Round'] for j in fourthround[i]) for i in teams]

# Create dictionary for round five matchups, same format as round four
values = [0] * len(teams)
for i in range(len(teams)):
    if i % 32 < 16:
        values[i] = [teams[32*floor(i/32)+j] for j in range(16,32)]
    else:
        values[i] = [teams[32*ceil(i/32)-j] for j in range(32,16, -1)]

fifthround = dict(zip(teams, values))

# Put fifth round probabilities in
results['Fifth Round'] = [sum(df.loc[i, j]*results.loc[j, 'Fourth Round']*results.loc[i, 'Fourth Round'] for j in fifthround[i]) for i in teams]

# Create dictionary for round six matchups, same format as round five
values = [0] * len(teams)
for i in range(len(teams)):
    if i % 64 < 32:
        values[i] = [teams[64*floor(i/64)+j] for j in range(32,64)]
    else:
        values[i] = [teams[64*ceil(i/64)-j] for j in range(64,32, -1)]


sixthround = dict(zip(teams, values))

# Put sixth round probabilities in
results['Sixth Round'] = [sum(df.loc[i, j]*results.loc[j, 'Fifth Round']*results.loc[i, 'Fifth Round'] for j in sixthround[i]) for i in teams]



# Create model and Indices
m = Model("March Madness")
rounds = results.columns.tolist()
weights = {'First Round' : 1, 'Second Round' : 2, 'Third Round' :4, 'Fourth Round' : 8, 'Fifth Round' : 16, 'Sixth Round' : 32}

# Create decision variables
x = m.addVars(teams, rounds, vtype = GRB.BINARY, name = 'x')

# Create objective function
m.setObjective(quicksum(weights[k] * x[i, k] * results.loc[i, k] for i in teams for k in rounds), GRB.MAXIMIZE)


# Create constraints

# Round 1 Constraints
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Duke', 'N Dakota St']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['VA Commonwealth', 'UCF']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Mississippi St', 'Liberty']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Virginia Tech', 'St Louis']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Maryland', 'Belmont']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['LSU', 'Yale']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Louisville', 'Minnesota']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Michigan St', 'Bradley']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Gonzaga', 'F Dickinson']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Syracuse', 'Baylor']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Marquette', 'Murray St']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Florida St', 'Vermont']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Buffalo', 'Arizona St']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Texas Tech', 'N Kentucky']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Nevada', 'Florida']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Michigan', 'Montana']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Virginia', 'Gardner Webb']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Mississippi', 'Oklahoma']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Wisconsin', 'Oregon']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Kansas St', 'UC Irvine']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Villanova', "St Mary's CA"]) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Purdue', 'Old Dominion']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Cincinnati', 'Iowa']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Tennessee', 'Colgate']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['North Carolina', 'Iona']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Utah St', 'Washington']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Auburn', 'New Mexico St']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Kansas', 'Northeastern']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Iowa St', 'Ohio St']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Houston', 'Georgia St']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Wofford', 'Seton Hall']) == 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in ['Kentucky', 'Abilene Chr']) == 1)

# Round 2 Constraints
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Duke', 'N Dakota St', 'VA Commonwealth', 'UCF']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Mississippi St', 'Liberty', 'Virginia Tech', 'St Louis']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Maryland', 'Belmont', 'LSU', 'Yale']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Louisville', 'Minnesota', 'Michigan St', 'Bradley']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Gonzaga', 'F Dickinson', 'Syracuse', 'Baylor']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Marquette', 'Murray St', 'Florida St', 'Vermont']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Buffalo', 'Arizona St', 'Texas Tech', 'N Kentucky']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Nevada', 'Florida', 'Michigan', 'Montana']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Virginia', 'Gardner Webb', 'Mississippi', 'Oklahoma']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Wisconsin', 'Oregon', 'Kansas St', 'UC Irvine']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Villanova', "St Mary's CA", 'Purdue', 'Old Dominion']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Cincinnati', 'Iowa', 'Tennessee', 'Colgate']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['North Carolina', 'Iona', 'Utah St', 'Washington']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Auburn', 'New Mexico St', 'Kansas', 'Northeastern']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Iowa St', 'Ohio St', 'Houston', 'Georgia St']) == 1)
m.addConstr(quicksum(x[i, 'Second Round'] for i in ['Wofford', 'Seton Hall', 'Kentucky', 'Abilene Chr']) == 1)

# Round 3 Constraints
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['Duke', 'N Dakota St', 'VA Commonwealth', 'UCF', 'Mississippi St', 'Liberty', 'Virginia Tech', 'St Louis']) == 1)
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['Maryland', 'Belmont', 'LSU', 'Yale', 'Louisville', 'Minnesota', 'Michigan St', 'Bradley']) == 1)
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['Gonzaga', 'F Dickinson', 'Syracuse', 'Baylor', 'Marquette', 'Murray St', 'Florida St', 'Vermont']) == 1)
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['Buffalo', 'Arizona St', 'Texas Tech', 'N Kentucky', 'Nevada', 'Florida', 'Michigan', 'Montana']) == 1)
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['Virginia', 'Gardner Webb', 'Mississippi', 'Oklahoma', 'Wisconsin', 'Oregon', 'Kansas St', 'UC Irvine']) == 1)
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['Villanova', "St Mary's CA", 'Purdue', 'Old Dominion', 'Cincinnati', 'Iowa', 'Tennessee', 'Colgate']) == 1)
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['North Carolina', 'Iona', 'Utah St', 'Washington', 'Auburn', 'New Mexico St', 'Kansas', 'Northeastern']) == 1)
m.addConstr(quicksum(x[i, 'Third Round'] for i in ['Iowa St', 'Ohio St', 'Houston', 'Georgia St', 'Wofford', 'Seton Hall', 'Kentucky', 'Abilene Chr']) == 1)

# Round 4 Constraints
m.addConstr(quicksum(x[i, 'Fourth Round'] for i in teams[0:16]) == 1)
m.addConstr(quicksum(x[i, 'Fourth Round'] for i in teams[16:32]) == 1)
m.addConstr(quicksum(x[i, 'Fourth Round'] for i in teams[32:48]) == 1)
m.addConstr(quicksum(x[i, 'Fourth Round'] for i in teams[48:64]) == 1)

# Round 5 Constraints
m.addConstr(quicksum(x[i, 'Fifth Round'] for i in teams[0:32]) == 1)
m.addConstr(quicksum(x[i, 'Fifth Round'] for i in teams[32:64]) == 1)

# Round 6 Constraints
m.addConstr(quicksum(x[i, 'Sixth Round'] for i in teams) == 1)

# Elimination Constraints
m.addConstrs(quicksum(x[i, k] for k in rounds[1:6]) <= 5*x[i, "First Round"] for i in teams)
m.addConstrs(quicksum(x[i, k] for k in rounds[2:6]) <= 4*x[i, "Second Round"] for i in teams)
m.addConstrs(quicksum(x[i, k] for k in rounds[3:6]) <= 3*x[i, "Third Round"] for i in teams)
m.addConstrs(quicksum(x[i, k] for k in rounds[4:6]) <= 2*x[i, "Fourth Round"] for i in teams)
m.addConstrs(quicksum(x[i, k] for k in rounds[5:6]) <= x[i, "Fifth Round"] for i in teams)

# Upset Constraints
m.addConstr(quicksum(x[i, 'First Round'] for i in teams[3::16]) >= 2)
m.addConstr(quicksum(x[i, 'First Round'] for i in teams[5::16]) >= 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in teams[9::16]) >= 1)
m.addConstr(quicksum(x[i, 'First Round'] for i in teams[13::16]) >= 1)

# Upper Seed Constraints
m.addConstr(quicksum(x[i, 'Fourth Round'] for i in teams[0::16]) <= 3)


# Optimize and record objective value
m.optimize()
objectiveScores = []
objectiveScores.append(m.ObjVal)

# Setup decision variable results from optimization in dataframe
resultsx = []
for v in m.getVars():
    #print("%s %g" % (v.varName, v.x))
    resultsx.append(v.x)
reshapedresultsx = [resultsx[i:i+6] for i in range(0, 384, 6)]
resultsDF = pd.DataFrame(reshapedresultsx, index = teams, columns=rounds)

#Compute bracket score based on how it matches 2019 bracket
bracketScores = []
bracketScore = 0
for i in teams:
    k = 0
    for j in rounds:
        if resultsDF.loc[i, j] == origninalBracket.loc[i, j] and origninalBracket.loc[i,j] == 1:
            bracketScore = bracketScore + 2**k
        k+=1
bracketScores.append(bracketScore)



# Repeat 9 more times 
for a in range(9):

    # Create new constraint forcing out a winning game to get a new bracket
    winningGames = [[i, j] for i in teams for j in rounds if resultsDF.loc[i, j] == 1]
    m.addConstr(quicksum(x[i, j] for [i, j] in winningGames) <= 62)

    # Optimize model with new constraint and record value
    m.optimize()
    objectiveScores.append(m.ObjVal)

    # Setup results from optimization in dataframe
    resultsx = []
    for v in m.getVars():
        #print("%s %g" % (v.varName, v.x))
        resultsx.append(v.x)
    reshapedresultsx = [resultsx[i:i+6] for i in range(0, 384, 6)]
    resultsDF = pd.DataFrame(reshapedresultsx, index = teams, columns=rounds)

    # Compute bracket score based on how it matches 2019 bracket
    bracketScore = 0
    for i in teams:
        k = 0
        for j in rounds:
            if resultsDF.loc[i, j] == origninalBracket.loc[i, j] and origninalBracket.loc[i,j] == 1:
                bracketScore = bracketScore + 2**k
            k+=1
    bracketScores.append(bracketScore)
    
# Print results
print(bracketScores)
print(objectiveScores)
# Out:
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 388 rows, 384 columns and 1684 nonzeros
# Model fingerprint: 0xff8c53dc
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
# Found heuristic solution: objective 37.5775295
# Presolve removed 48 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 340 rows, 336 columns, 1620 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.567219e+01, 60 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   95.67219    0    2   37.57753   95.67219   155%     -    0s
# H    0     0                      95.5566699   95.67219  0.12%     -    0s
#      0     0   95.67219    0    2   95.55667   95.67219  0.12%     -    0s
#
# Explored 1 nodes (60 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 95.5567 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.555666994566e+01, best bound 9.555666994566e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 389 rows, 384 columns and 1747 nonzeros
# Model fingerprint: 0x246b1ca1
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R388 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 48 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 341 rows, 336 columns, 1679 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.566923e+01, 61 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   95.66923    0    2   37.57753   95.66923   155%     -    0s
# H    0     0                      95.3821326   95.66923  0.30%     -    0s
# H    0     0                      95.5262699   95.66923  0.15%     -    0s
# H    0     0                      95.5279297   95.66923  0.15%     -    0s
#
# Explored 1 nodes (61 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 95.5279 95.5263 95.3821 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.552792966562e+01, best bound 9.552792966562e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 390 rows, 384 columns and 1810 nonzeros
# Model fingerprint: 0x0d8e8166
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R389 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 48 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 342 rows, 336 columns, 1738 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.566923e+01, 61 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   95.66923    0    2   37.57753   95.66923   155%     -    0s
# H    0     0                      95.3821326   95.66923  0.30%     -    0s
#      0     0   95.52710    0    4   95.38213   95.52710  0.15%     -    0s
# H    0     1                      95.5262699   95.52710  0.00%     -    0s
#
# Cutting planes:
#   Cover: 2
#
# Explored 1 nodes (64 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 95.5263 95.3821 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.552626994566e+01, best bound 9.552626994566e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 391 rows, 384 columns and 1873 nonzeros
# Model fingerprint: 0xc51cb730
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R390 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 48 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 343 rows, 336 columns, 1797 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.566923e+01, 64 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   95.66923    0    2   37.57753   95.66923   155%     -    0s
# H    0     0                      95.3821326   95.66923  0.30%     -    0s
#      0     0   95.52710    0    4   95.38213   95.52710  0.15%     -    0s
#      0     0   95.51727    0    4   95.38213   95.51727  0.14%     -    0s
# H    0     0                      95.4598699   95.51727  0.06%     -    0s
# H    0     0                      95.5152699   95.51727  0.00%     -    0s
#      0     0   95.51727    0    4   95.51527   95.51727  0.00%     -    0s
#
# Explored 1 nodes (69 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 95.5153 95.4599 95.3821 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.551526994566e+01, best bound 9.551526994566e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 392 rows, 384 columns and 1936 nonzeros
# Model fingerprint: 0xaf0e1b87
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R391 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 50 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 342 rows, 336 columns, 1737 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.566923e+01, 61 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   95.66923    0    2   37.57753   95.66923   155%     -    0s
# H    0     0                      95.3821326   95.66923  0.30%     -    0s
#      0     0   95.51810    0    4   95.38213   95.51810  0.14%     -    0s
#      0     0   95.50827    0    2   95.38213   95.50827  0.13%     -    0s
# H    0     0                      95.4598699   95.50827  0.05%     -    0s
# H    0     0                      95.4975297   95.50827  0.01%     -    0s
#      0     0   95.50827    0    2   95.49753   95.50827  0.01%     -    0s
#
# Explored 1 nodes (66 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 95.4975 95.4599 95.3821 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.549752966562e+01, best bound 9.549752966562e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 393 rows, 384 columns and 1999 nonzeros
# Model fingerprint: 0x507f9ce7
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R392 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 50 rows and 48 columns
# Presolve time: 0.00s
# Presolved: 343 rows, 336 columns, 1796 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.566923e+01, 59 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   95.66923    0    2   37.57753   95.66923   155%     -    0s
# H    0     0                      95.3821326   95.66923  0.30%     -    0s
#      0     0   95.51810    0    4   95.38213   95.51810  0.14%     -    0s
#      0     0   95.50827    0    2   95.38213   95.50827  0.13%     -    0s
# H    0     0                      95.4598699   95.50827  0.05%     -    0s
# H    0     0                      95.4865297   95.50827  0.02%     -    0s
#      0     0   95.50827    0    2   95.48653   95.50827  0.02%     -    0s
#
# Explored 1 nodes (64 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 95.4865 95.4599 95.3821 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.548652966562e+01, best bound 9.548652966562e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 394 rows, 384 columns and 2062 nonzeros
# Model fingerprint: 0x05022a30
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R393 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 52 rows and 48 columns
# Presolve time: 0.01s
# Presolved: 342 rows, 336 columns, 1736 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.566923e+01, 61 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   95.66923    0    2   37.57753   95.66923   155%     -    0s
# H    0     0                      95.3821326   95.66923  0.30%     -    0s
#      0     0   95.51810    0    4   95.38213   95.51810  0.14%     -    0s
# H    0     0                      95.4714699   95.51810  0.05%     -    0s
#
# Explored 1 nodes (64 simplex iterations) in 0.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 95.4715 95.3821 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.547146994566e+01, best bound 9.547146994566e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 395 rows, 384 columns and 2125 nonzeros
# Model fingerprint: 0x18c0914c
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R394 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 52 rows and 48 columns
# Presolve time: 0.01s
# Presolved: 343 rows, 336 columns, 1795 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.566923e+01, 59 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   95.66923    0    2   37.57753   95.66923   155%     -    0s
# H    0     0                      95.3821326   95.66923  0.30%     -    0s
#      0     0   95.51810    0    4   95.38213   95.51810  0.14%     -    0s
#      0     0   95.50827    0    2   95.38213   95.50827  0.13%     -    0s
# H    0     0                      95.4598699   95.50827  0.05%     -    0s
# H    0     0                      95.4654699   95.50827  0.04%     -    0s
#
# Cutting planes:
#   Zero half: 1
#
# Explored 1 nodes (63 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 95.4655 95.4599 95.3821 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.546546994566e+01, best bound 9.546546994566e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 396 rows, 384 columns and 2188 nonzeros
# Model fingerprint: 0x60fd858a
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R395 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 52 rows and 48 columns
# Presolve time: 0.01s
# Presolved: 344 rows, 336 columns, 1854 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.566923e+01, 57 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   95.66923    0    2   37.57753   95.66923   155%     -    0s
# H    0     0                      95.3821326   95.66923  0.30%     -    0s
#      0     0   95.51810    0    4   95.38213   95.51810  0.14%     -    0s
#      0     0   95.50827    0    2   95.38213   95.50827  0.13%     -    0s
# H    0     0                      95.4598699   95.50827  0.05%     -    0s
# H    0     0                      95.4604699   95.50827  0.05%     -    0s
#      0     0 infeasible    0        95.46047   95.46047  0.00%     -    0s
#
# Cutting planes:
#   Zero half: 1
#
# Explored 1 nodes (65 simplex iterations) in 0.05 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 95.4605 95.4599 95.3821 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.546046994566e+01, best bound 9.546046994566e+01, gap 0.0000%
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 397 rows, 384 columns and 2251 nonzeros
# Model fingerprint: 0xd0eecf3f
# Variable types: 0 continuous, 384 integer (384 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [4e-11, 5e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
#
# MIP start from previous solve did not produce a new incumbent solution
# MIP start from previous solve violates constraint R396 by 1.000000000
#
# Found heuristic solution: objective 37.5775295
# Presolve removed 53 rows and 48 columns
# Presolve time: 0.01s
# Presolved: 344 rows, 336 columns, 1853 nonzeros
# Variable types: 0 continuous, 336 integer (336 binary)
#
# Root relaxation: objective 9.566923e+01, 61 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   95.66923    0    2   37.57753   95.66923   155%     -    0s
# H    0     0                      95.3821326   95.66923  0.30%     -    0s
#      0     0   95.51810    0    4   95.38213   95.51810  0.14%     -    0s
#      0     0   95.50827    0    2   95.38213   95.50827  0.13%     -    0s
# H    0     0                      95.4598699   95.50827  0.05%     -    0s
#      0     0     cutoff    0        95.45987   95.45987  0.00%     -    0s
#
# Cutting planes:
#   Zero half: 2
#
# Explored 1 nodes (69 simplex iterations) in 0.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 95.4599 95.3821 37.5775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.545986994566e+01, best bound 9.545986994566e+01, gap 0.0000%
# [89, 89, 89, 90, 89, 90, 87, 89, 88, 89]
# [95.55666994566013, 95.52792966561836, 95.52626994566013, 95.51526994566014, 95.49752966561836, 95.48652966561836, 95.47146994566012, 95.46546994566013, 95.46046994566012, 95.45986994566015]
